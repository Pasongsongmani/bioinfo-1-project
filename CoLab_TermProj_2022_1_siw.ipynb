# %% [markdown]
# # 생물정보학 및 실습 1 - Term Project용 환경 셋업
#
# ```
# 생물정보학 및 실습 1
# 서울대학교 협동과정 생물정보학전공 2022년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Term Project를 할 수 있도록 환경을 준비해 줍니다. 터미널 사용이 원활하지 않은 상태이고, 데이터를 오랫동안 보관하기 어렵기 때문에 되도록 개인용 컴퓨터에서 [Anaconda](https://www.anaconda.com/)나 [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) 등을 설치하고 사용하시는 것이 편하지만, 개인용 컴퓨터 사양이 부족한 경우에는 Google CoLab을 사용할 수도 있습니다. 개인용 컴퓨터를 쓸 때는 Windows에서는 [WSL2](https://docs.microsoft.com/en-us/windows/wsl/install-win10)를 쓰시면 리눅스 커맨드라인 환경을 쓸 수 있습니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. **이번엔 스크립트 파일을 편집해야 하기 때문에 Google Drive 마운트를 하지 않으면 vim등 콘솔에서 쓸 수 있는 에디터를 쓰셔야 합니다.** 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다. Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 저장공간이 충분하므로 이 부분은 생략하고 지나갑니다.

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 따로 실습용 [Bioconda](https://bioconda.github.io/) 환경을 구축해서 이 노트북을 그 환경 안에서 띄우시면 됩니다.
#
# CoLab을 쓰시는 분들은 다음에 따라서 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %% [markdown]
# 설정이 끝났으면, 이제 콘솔을 열어서 터미널로 접속할 수 있는 통로를 열어줍니다.

# %% [markdown]
# ## 시퀀싱 데이터 다운로드
# 이제 실습 수업에서 필요한 시퀀싱 데이터를 다운로드 받아서 설치합시다. 드라이브 공간만 충분하면 데이터는 계속 저장돼 있기 때문에 학기 전체를 통해서 딱 한 번만 하시면 됩니다. Colab에서는 작업용 데이터를 Google Drive 폴더 아래의 `binfo-datapack1`에 저장합니다. 실습용 데이터는 `/content/drive/MyDrive/binfo1-datapack1`에 풀리게 됩니다.
#
# ### (Option 1) Google CoLab에서 접속한 경우
# 1. [Google Drive 공유폴더](https://drive.google.com/drive/folders/1Y190lbO42VEzjjQkgoxNf_EcZJlHyZa1?usp=sharing)에 접속합니다.
# 1. 중간 제목줄의 "binfo1-datapack1 ▾"에서 ▾을 누릅니다.
# 1. Add shortcut to Drive를 누릅니다.
# 1. My Drive를 선택해서 ADD SHORTCUT 버튼을 누릅니다.
# 1. 다음 cell을 실행해서 링크가 제대로 들어왔는지 확인합니다. (바로 확인되지 않으면 3–5분 정도 기다렸다가 하면 됩니다.)
# 1. 제대로 확인되면 다음으로 넘어갑니다.

# %%
import os
print(os.getcwd())
# Out:
# /home/pasongsongmani

# %% [markdown]
# ### (Option 2) CoLab외의 다른 환경에서 접속한 경우
# 본인 컴퓨터나 연구실 워크스테이션 등에서 작업하는 경우에는 다음 명령어로 다운로드 받으시면 됩니다. 첫 번째에는 wget이 접속오류를 내는 경우가 많으니, 접속에러가 발생하면 다시 한 번 실행해 보세요. `/content/drive/Mydrive` 부분은 원하는 저장 경로로 바꿔서 지정하시면 됩니다.

# %%
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C /home/pasongsongmani/ -xf -
# Out:
# --2022-05-06 13:57:36--  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Resolving hyeshik.qbio.io (hyeshik.qbio.io)... 147.47.203.129, 147.47.203.129, 45.63.39.231
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# WARNING: cannot verify hyeshik.qbio.io's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6424668160 (6.0G) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                    16%[==>                 ]   1.00G  11.2MB/s    in 92s
#
# 2022-05-06 13:59:08 (11.2 MB/s) - Connection closed at byte 1078066901. Retrying.
#
# --2022-05-06 13:59:09--  (try: 2)  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# WARNING: cannot verify hyeshik.qbio.io's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
# ...

# %% [markdown]
# 그리고, GENCODE Annotation 데이터도 미리 받아서 저장해 둡니다. 에러가 나면 다시 한 번 실행해 봅니다.

# %%
# !wget --no-check-certificate -O /home/pasongsongmani/binfo1-datapack1/gencode.gtf.gz http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Out:
# --2022-05-06 14:07:02--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.138, 205.251.193.178, 205.251.195.185, ...
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28359457 (27M) [application/octet-stream]
# Saving to: ‘/home/pasongsongmani/gencode.gtf.gz’
#
# /home/pasongsongman 100%[===================>]  27.04M   134KB/s    in 3m 44s
#
# 2022-05-06 14:10:46 (124 KB/s) - ‘/home/pasongsongmani/gencode.gtf.gz’ saved [28359457/28359457]

# %% [markdown]
# 다루기 쉽도록 Annotation 압축을 풉니다.

# %%
# !gzip -h
# Out:
# Usage: gzip [OPTION]... [FILE]...
# Compress or uncompress FILEs (by default, compress FILES in-place).
#
# Mandatory arguments to long options are mandatory for short options too.
#
#   -c, --stdout      write on standard output, keep original files unchanged
#   -d, --decompress  decompress
#   -f, --force       force overwrite of output file and compress links
#   -h, --help        give this help
#   -k, --keep        keep (don't delete) input files
#   -l, --list        list compressed file contents
#   -L, --license     display software license
#   -n, --no-name     do not save or restore the original name and timestamp
#   -N, --name        save or restore the original name and timestamp
#   -q, --quiet       suppress all warnings
#   -r, --recursive   operate recursively on directories
#       --rsyncable   make rsync-friendly archive
#   -S, --suffix=SUF  use suffix SUF on compressed files
#       --synchronous synchronous output (safer if system crashes, but slower)
# ...

# %%
# !gunzip /home/pasongsongmani/gene_code/gencode.gtf.gz
# Out:
# gzip: /home/pasongsongmani/gene_code/gencode.gtf.gz: No such file or directory

# %% [markdown]
# ### 파일 체크섬 확인
#
# 받은 데이터의 MD5 체크섬을 확인합니다. 한참 걸립니다. 각 파일들의 원래 체크섬은 다음과 같습니다. 한 번 비교해 보세요.
#
# ```
# 140aaf30bcb9276cc716f8699f04ddd6  CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  RPF-siLuc.bam.bai
# ```

# %%
# !md5sum /home/pasongsongmani/binfo1-datapack1/*
# Out:
# 140aaf30bcb9276cc716f8699f04ddd6  /home/pasongsongmani/binfo1-datapack1/CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  /home/pasongsongmani/binfo1-datapack1/CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  /home/pasongsongmani/binfo1-datapack1/RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  /home/pasongsongmani/binfo1-datapack1/RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  /home/pasongsongmani/binfo1-datapack1/RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  /home/pasongsongmani/binfo1-datapack1/RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  /home/pasongsongmani/binfo1-datapack1/RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  /home/pasongsongmani/binfo1-datapack1/RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  /home/pasongsongmani/binfo1-datapack1/RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  /home/pasongsongmani/binfo1-datapack1/RPF-siLin28a.bam.bai
# ...

# %%
# !ls -al /home/pasongsongmani/binfo1-datapack1*
# Out:
# total 6908416
# drwxr-xr-x  3 pasongsongmani pasongsongmani       4096 May 11 17:59 .
# drwxr-xr-x 16 pasongsongmani pasongsongmani       4096 May 11 18:07 ..
# drwxr-xr-x  2 pasongsongmani pasongsongmani       4096 May  6 14:19 .ipynb_checkpoints
# -rw-r--r--  1 pasongsongmani pasongsongmani 1370036258 May  6  2021 CLIP-35L33G.bam
# -rw-r--r--  1 pasongsongmani pasongsongmani    3118336 May  6  2021 CLIP-35L33G.bam.bai
# -rw-r--r--  1 pasongsongmani pasongsongmani 1003658801 May  6  2021 RNA-control.bam
# -rw-r--r--  1 pasongsongmani pasongsongmani    2276104 May  6  2021 RNA-control.bam.bai
# -rw-r--r--  1 pasongsongmani pasongsongmani 1260991122 May  6  2021 RNA-siLin28a.bam
# -rw-r--r--  1 pasongsongmani pasongsongmani    2710744 May  6  2021 RNA-siLin28a.bam.bai
# -rw-r--r--  1 pasongsongmani pasongsongmani  981684502 May  6  2021 RNA-siLuc.bam
# -rw-r--r--  1 pasongsongmani pasongsongmani    2606104 May  6  2021 RNA-siLuc.bam.bai
# ...

# %%
# !ls -al /home/pasongsongmani/gene_code*
# Out:
# total 890736
# drwxr-xr-x  2 pasongsongmani pasongsongmani      4096 May 11 17:55 .
# drwxr-xr-x 16 pasongsongmani pasongsongmani      4096 May 12 21:14 ..
# -rw-r--r--  1 pasongsongmani pasongsongmani    855103 May  6 21:38 gencode-exons-containing-startcodon.bed
# -rw-r--r--  1 pasongsongmani pasongsongmani  26842797 May  6 21:38 gencode-plusexon.gtf
# -rw-r--r--  1 pasongsongmani pasongsongmani   1063832 May  6 21:37 gencode-start.gtf
# -rw-r--r--  1 pasongsongmani pasongsongmani 883334756 Mar  9  2021 gencode.gtf

# %% [markdown]
# 실습에 필요한 프로그램들 몇 가지를 추가로 설치합니다.

# %%
# !conda install -y subread
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ## Transcript count table 마련하기
#
# 제공된 alignment와 annotation 파일들을 이용해서 transcript별 read count를 구해봅니다. 실제 연구에서는 multi-mapping 등을 고려해야 하지만, 여기서는 단순화해서 모두 무시합니다. 데이터가 있는 곳으로 이동해서 작업합시다.

# %%
# %cd /home/pasongsongmani/binfo1-datapack1/
# Out:
# /home/pasongsongmani/binfo1-datapack1

# %%
# !featureCounts -a ../gene_code/gencode.gtf -o read-counts.txt *.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 7 BAM files                                      ||
# ||                           o CLIP-35L33G.bam                                ||
# ||                           o RNA-control.bam                                ||
# ||                           o RNA-siLin28a.bam                               ||
# ...

# %% [markdown]
# 결과를 pandas로 읽어와 봅니다.

# %%
import pandas as pd
cnts = pd.read_csv('read-counts.txt', sep='\t', comment='#', index_col=0)
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %% [markdown]
# 이제 한 번 대충 그림을 그려 봅니다.

# %%
cnts['clip_enrichment'] = cnts['CLIP-35L33G.bam'] / cnts['RNA-control.bam']
cnts['rden_change'] = (cnts['RPF-siLin28a.bam'] / cnts['RNA-siLin28a.bam']) / (cnts['RPF-siLuc.bam'] / cnts['RNA-siLuc.bam'])
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(np.log2(cnts['clip_enrichment']),
           np.log2(cnts['rden_change']))
# Out:
# /home/pasongsongmani/anaconda3/envs/ddocent_env/lib/python3.10/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# 이 그림에는 문제가 많이 있습니다. 논문의 그림처럼 한 번 만들어 봅시다~

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))

plt.ylim([-3,2])
plt.xlim([-6,6])

x = np.array(np.log2(cnts['clip_enrichment']))
y = np.array(np.log2(cnts['rden_change']))

box1 = {'boxstyle': 'square',
        'ec': (1.0, 1.0, 1.0),
        'fc': (1.0, 1.0, 1.0)}

corr = cnts[['clip_enrichment','rden_change']].corr().iloc[0,1]
ax.scatter(x, y, s = 1, alpha = 0.3, color = "black")
ax.text(-5.5, -2.5,"r = {:.4}".format(corr), fontsize=14, bbox = box1)


plt.xlabel(r'LIN28A CLIP enrichment (log$_2$)',fontsize=17)
plt.ylabel('Ribosome density change\nupon $Lin28a$ knockdown (log$_2$)',fontsize=17)
plt.grid()

plt.show()
# Out:
# /home/pasongsongmani/anaconda3/envs/ddocent_env/lib/python3.10/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## Protein localization 반영하기
#
# 논문 그림에서는 protein localization을 반영해서 색으로 나타냈습니다. 이것을 한 번 구현해 봅시다. 각 gene product의 localization을 따로 구하려면 좀 귀찮기 때문에 미리 모아 두었습니다. UniProt에서 매핑된 데이터를 토대로 아주 명확한 것만 일부 정리한 것입니다. 이것도 마찬가지로 처음엔 에러가 나기도 하니까, 다시 실행해보면 거의 잘 됩니다~

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
mouselocal = pd.read_csv('https://hyeshik.qbio.io/binfo/mouselocalization-20210507.txt', sep='\t')
mouselocal.head()
# Out:
#               gene_id            Gene names       type
# 0  ENSMUSG00000000001                 Gnai3  cytoplasm
# 1  ENSMUSG00000000028  Cdc45 Cdc45l Cdc45l2    nucleus
# 2  ENSMUSG00000000049            Apoh B2gp1  cytoplasm
# 3  ENSMUSG00000000058                  Cav2  cytoplasm
# 4  ENSMUSG00000000085                 Scmh1    nucleus

# %% [markdown]
# 이제 이 localization 데이터와 위에서 만든 scatter를 결합해서 논문 그림과 비슷하게 만들어 봅시다.

# %%
cnts['gene_id'] = [name[0] for name in cnts.index.str.split('.')]
new_cnts = pd.merge(cnts, mouselocal, how='left', on="gene_id").dropna()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array(np.log2(new_cnts['clip_enrichment']))
y = np.array(np.log2(new_cnts['rden_change']))

dict_local = {'integral membrane': 'red', 'nucleus': 'blue', 'cytoplasm': 'green'}

fig, ax = plt.subplots(1, 1, figsize =(5,5))
plt.xlim([-5,5])
plt.ylim([-3,2])
plt.grid()

for group in np.unique(new_cnts.type):
    ix = np.where(new_cnts.type == group)
    ax.scatter(x[ix], y[ix], c = dict_local[group], label = group, s = 2, alpha = 0.3)

ax.legend()
plt.xlabel(r'LIN28A CLIP enrichment (log$_2$)',fontsize=17)
plt.ylabel('Ribosome density change\nupon $Lin28a$ knockdown (log$_2$)',fontsize=17)
plt.show()
# Out:
# /home/pasongsongmani/anaconda3/envs/ddocent_env/lib/python3.10/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
